# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
file=(r"C:\Users\DELL\Downloads\kc_house_data.csv")
df=pd.read_csv(file)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
for i in ['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']:
    print("the coorelation is :",df[i].corr(df['price']))
    plt.scatter(df[i],df['price'])
    plt.ylabel("price")
    plt.xlabel(i)
    plt.show()
# Out:
# the coorelation is : 0.3083495981456382
# the coorelation is : 0.5251375054139615
# the coorelation is : 0.7020350546118004
# the coorelation is : 0.08966086058710013
# the coorelation is : 0.25679388755071847
# the coorelation is : 0.26636943403060215
# the coorelation is : 0.39729348829450456
# the coorelation is : 0.0363617891289975
# the coorelation is : 0.6674342560202366
# the coorelation is : 0.6055672983560781
# the coorelation is : 0.3238160207119834
# the coorelation is : 0.05401153149479271
# the coorelation is : 0.12643379344089312
# the coorelation is : -0.053202854298325664
# the coorelation is : 0.30700347999521854
# the coorelation is : 0.021626241039306694
# the coorelation is : 0.5853789035795679
# the coorelation is : 0.08244715251948591

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23216\372785905.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# ...

# %%
sns.heatmap(correlation_matrix,cmap="RdBu") 
plt.show()

# %%
#the columns selected vs 'price' are: grade,sqft_living,sqft_above,sqft_living15,bathrooms,view,sqft_basement,bedrooms,lat

# %%
for i in ['price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']:
    df[i]=(df[i]-df[i].mean())/df[i].std()

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000 -0.866697 -0.398728  -1.447430    -0.979812
# 1  6414100192  20141209T000000 -0.005688 -0.398728   0.175603     0.533622
# 2  5631500400  20150225T000000 -0.980827 -1.473925  -1.447430    -1.426221
# 3  2487200875  20141209T000000  0.174086  0.676469   1.149422    -0.130547
# 4  1954400510  20150218T000000 -0.081956 -0.398728  -0.149004    -0.435412
#
#    sqft_lot    floors  waterfront      view  ...     grade  sqft_above  \
# 0 -0.228316 -0.915406   -0.087171 -0.305752  ... -0.558823   -0.734691
# 1 -0.189881  0.936484   -0.087171 -0.305752  ... -0.558823    0.460830
# 2 -0.123296 -0.915406   -0.087171 -0.305752  ... -1.409554   -1.229805
# 3 -0.244009 -0.915406   -0.087171 -0.305752  ... -0.558823   -0.891678
# 4 -0.169649 -0.915406   -0.087171 -0.305752  ...  0.291909   -0.130892
#
#    sqft_basement  yr_built  yr_renovated   zipcode       lat      long  \
# ...

# %%
from sklearn.neural_network import MLPRegressor

# %%
X=df[['bedrooms', 'bathrooms', 'sqft_living','sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade','sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode','lat', 'long', 'sqft_living15', 'sqft_lot15']]
Y=df["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
nn_model = MLPRegressor(hidden_layer_sizes=(100, ), max_iter=1000, random_state=42)

# %%
nn_model.fit(X_train, y_train)
# Out:
# MLPRegressor(max_iter=1000, random_state=42)

# %%
y_pred = nn_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 0.1407578758285822

# %%
r12 = r2_score(y_test, y_pred)
r12
# Out:
# 0.8745065890169192

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X=df[['bedrooms', 'bathrooms', 'sqft_living','sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade','sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode','lat', 'long', 'sqft_living15', 'sqft_lot15']]
Y=df["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error (Random Forest): {mse}')
# Out:
# Mean Squared Error (Random Forest): 0.16918604883788546

# %%
r1r = r2_score(y_test, y_pred)
r1r
# Out:
# 0.8491613045846702

# %%
# !pip install lightgbm

# %%
from lightgbm import LGBMRegressor

# %%
X=df[['bedrooms', 'bathrooms', 'sqft_living','sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade','sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode','lat', 'long', 'sqft_living15', 'sqft_lot15']]
Y=df["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
lgbm_model = LGBMRegressor(random_state=42)

# %%
lgbm_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002426 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2339
# [LightGBM] [Info] Number of data points in the train set: 17290, number of used features: 18
# [LightGBM] [Info] Start training from score -0.006320
# LGBMRegressor(random_state=42)

# %%
y_pred = lgbm_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error (LightGBM): {mse}')
# Out:
# Mean Squared Error (LightGBM): 0.13487773049299054

# %%
r2r = r2_score(y_test, y_pred)
r2r
# Out:
# 0.8797490629523621

# %%
# !pip install catboost

# %%
from catboost import CatBoostRegressor

# %%
X=df[['bedrooms', 'bathrooms', 'sqft_living','sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade','sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode','lat', 'long', 'sqft_living15', 'sqft_lot15']]
Y=df["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
catboost_model = CatBoostRegressor(iterations=100, depth=6, learning_rate=0.1, loss_function='RMSE', random_state=42)

# %%
catboost_model.fit(X_train, y_train, verbose=0)

# %%
y_pred = catboost_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error (CatBoost): {mse}')
# Out:
# Mean Squared Error (CatBoost): 0.12898979196086693

# %%
r2r = r2_score(y_test, y_pred)
r2rr
# Out:
# 0.8849984849524124

# %% [markdown]
# **The best first model for this problem is the `CatBoostRegressor`.**
#
# **The best second model is the `LGBMRegressor`.**
#
# **The best third model is the `MLPRegressor`.**
#
# **The best fourth model is the `RandomForestRegressor`.**
